# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ashwi\Downloads\loan_data.csv")
df.head(10)
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_3656\1861737435.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\ashwi\Downloads\loan_data.csv")
#                     BORROWER_NAME            CITY STATE    ZIP  \
# 0                  ABC HOBBYCRAFT      EVANSVILLE    IN  47711
# 1     LANDMARK BAR & GRILLE (THE)       NEW PARIS    IN  46526
# 2           WHITLOCK DDS, TODD M.     BLOOMINGTON    IN  47401
# 3   BIG BUCKS PAWN & JEWELRY, LLC    BROKEN ARROW    OK  74012
# 4     ANASTASIA CONFECTIONS, INC.         ORLANDO    FL  32801
# 5  B&T SCREW MACHINE COMPANY, INC      PLAINVILLE    CT   6062
# 6   MIDDLE ATLANTIC SPORTS CO INC           UNION    NJ   7083
# 7                 WEAVER PRODUCTS     SUMMERFIELD    FL  34491
# 8                TURTLE BEACH INN  PORT SAINT JOE    FL  32456
# 9         INTEXT BUILDING SYS LLC     GLASTONBURY    CT   6073
#
# ...

# %%
df.columns
# Out:
# Index(['BORROWER_NAME', 'CITY', 'STATE', 'ZIP', 'BANK', 'BANK_STATE',
#        'INDUSTRY_ID', 'APPROVAL_DATE', 'APPROVAL_YEAR', 'TERM',
#        'EMPLOYEE_COUNT', 'IS_NEW', 'JOBS_CREATED_COUNT', 'JOBS_RETAINED_COUNT',
#        'FRANCHISE_CODE', 'IS_URBAN', 'IS_REVOLVER', 'IS_LOW_DOC',
#        'DEFAULT_DATE', 'DISBURSEMENT_DATE', 'DISBURSEMENT_AMOUNT',
#        'BALANCE_AMOUNT', 'LOAN_STATUS', 'CHARGE_OFF_AMOUNT', 'LOAN_AMOUNT',
#        'SBA_APPROVED_AMOUNT', 'TREASURY_YIELD', 'CPI_INDEX', 'GDP',
#        'MORTGAGE_30_US_FIXED', 'UNRATE', 'INDPRO_INDEX', 'UMCSENT_INDEX',
#        'CSUSHPINSA_INDEX', 'CP_INDEX', 'FEDFUNDS_RATE'],
#       dtype='object')

# %%
df[df['APPROVAL_YEAR'] < 1996]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[int(df['APPROVAL_YEAR']) < 1996]
#
# File c:\Users\ashwi\anaconda3\Lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>
